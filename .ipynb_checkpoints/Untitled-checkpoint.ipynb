# %%
from ipywidgets import interact

# %%
def square(x):
    return x * x

# %%
interact(square, x=10);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…

# %%
import nbinteract as nbi
nbi.publish('benjcabalona1029/benjcabalona1029.github.io/master', 'Untitled.ipynb')
# Out:
# Saving notebook... Saved 'Untitled.ipynb'.
# Converting notebook...
# Successfully converted!
#
# <a href="Untitled.html" target="_blank" download>Click to download your webpage.</a>
#
# To host your webpage, see the documentation:
# <a href="https://www.nbinteract.com/tutorial/tutorial_publishing.html"
#         target="_blank">
#     https://www.nbinteract.com/tutorial/tutorial_publishing.html
# </a>
